# %%
import pandas as pd
# load imdb dataset as pandas dataframe"
df1 = pd.read_csv('./Desktop/imdb_1000.csv')
print(df1)
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
df.head(5)
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
#">The `bikes.csv` dataset contains information about the number of bicycles that used certain bicycle lanes in Montreal in the year 2012."
df2 = pd.read_csv('./Desktop/bikes.csv')
print(df2)
# Out:
#     Date;;Rachel / Papineau;Berri1;Maisonneuve_2;Maisonneuve_1;Brébeuf;Parc;PierDup;CSC (Côte Sainte-Catherine);Pont_Jacques_Cartier
# 0            01/01/2012;00:00;16;35;51;38;5;26;10;0;27
# 1           02/01/2012;00:00;43;83;153;68;11;53;6;1;21
# 2          03/01/2012;00:00;58;135;248;104;2;89;3;2;15
# 3         04/01/2012;00:00;61;144;318;116;2;111;8;1;19
# 4         05/01/2012;00:00;95;197;330;124;6;97;13;2;16
# 5           06/01/2012;00:00;75;146;244;98;4;86;4;0;17
# 6             07/01/2012;00:00;54;98;108;80;5;53;6;2;9
# 7           08/01/2012;00:00;63;95;98;62;13;64;11;1;23
# 8       09/01/2012;00:00;173;244;432;165;9;198;12;2;23
# 9       10/01/2012;00:00;241;397;563;238;6;275;18;3;46
# 10      11/01/2012;00:00;194;273;443;182;7;258;12;0;20
# 11        12/01/2012;00:00;63;157;261;134;3;137;9;1;15
# 12             13/01/2012;00:00;0;75;105;41;4;64;2;0;1
# 13              14/01/2012;00:00;1;32;56;54;0;19;0;0;3
# 14              15/01/2012;00:00;0;54;60;33;0;18;0;0;2
# ...

# %%
df2.head(3)
# Out:
#   Date;;Rachel / Papineau;Berri1;Maisonneuve_2;Maisonneuve_1;Brébeuf;Parc;PierDup;CSC (Côte Sainte-Catherine);Pont_Jacques_Cartier
# 0          01/01/2012;00:00;16;35;51;38;5;26;10;0;27
# 1         02/01/2012;00:00;43;83;153;68;11;53;6;1;21
# 2        03/01/2012;00:00;58;135;248;104;2;89;3;2;15

# %%
#"## Selecting columns\n",
#    "When you read a CSV, you get a kind of object called a DataFrame, which is made up of rows and columns. You get columns out of a DataFrame the same way you get elements out of a dictionary."
# ifdb_1000 columns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df1 = pd.read_csv('./Desktop/imdb_1000.csv')
cols = df1.columns[:]
#print(df[cols])
 #"# what are the datatypes of values in columns"
t1 = df1.dtypes
#print(t1)
#    "# list first 5 movie titles"
#print(df1.title.head(5))

# "# show only movie title and genre"

#print(df1[['title','genre']])

#"On the inside, the type of a column is`pd.Series`and pandas Series are internally numpy arrays. If you add ``.values`` to the end of any Series, you'll get its internal **numpy array**."

#    "# show the type of duration column"
#print(df1.duration.dtype)

#    "# show duration values of movies as numpy arrays"
ar = df1.duration.values
#print(ar)

#     "## Applying functions to columns\n",

#    "Use `.apply` function to apply any function to each element of a column."
#    "# convert all the movie titles to uppercase"
df1['title'] = df1['title'].str.upper() 
#print(df1.title)

#    "## Plotting a column\n",
#df1.plot(x='title',y='duration')

#     "# plot the bikers travelling to Berri1 over the year"
df2 = pd.read_csv('./Desktop/bikes.csv')
#print(df2)
#""""ASK THISSS"" 

#     "# plot all the columns of bikes_df"
df3 = pd.DataFrame(np.random.rand(366,1))
df3.plot(subplots=True)
plt.tight_layout()
#plt.show()

#    "Get count of unique values in a particular column/Series."
#pd.value_counts(df2.Berri1)
#"""""""""""""""""""ASK THIS """

#    "# what are the unique genre in imdb_df?"
#print(df1['genre'].unique())

#     "# plotting value counts of unique genres as a bar chart"
m = pd.value_counts(df1.genre)
#m.plot(kind='bar')

#    "# plotting value counts of unique genres as a pie chart"
m = pd.value_counts(df1.genre)
m.plot(kind='pie')

#"## Index\n",
#    "### DATAFRAME = COLUMNS + INDEX + ND DATA\n",
#    "### SERIES = INDEX + 1-D DATA\n",
#    "**Index** or (**row labels**) is one of the fundamental data structure of pandas. It can be thought of as an **immutable array** and an **ordered set**.\n",
#    "> Every row is uniquely identified by its index value."

#    "# show index of bikes_df"
k = df2.index.values
#print(k)

#    "# get row for date 2012-01-01"
m = '2012-01-01'
#Index_label =    df2[df2['Date'] == m].index.tolist() 
#print(Index_label)
#""""""" ASSSSK THIIIIS"""

#    "#### To get row by integer index:\n",
#     "Use ``.iloc[]`` for purely integer-location based indexing for selection by position."
#df2.iloc[['2012-01-01']]

#    "# show 11th row of imdb_df using iloc"
rowData = df1.loc[11]
#print(rowData)

#    "## Selecting rows where column has a particular value"
#   "# select only those movies where genre is adventure"

r = df1.loc[df1['genre'] == 'Adventure']
#print(r['title'])

#    "# which genre has highest number of movies with star rating above 8 and duration more than 130 minutes?"
r = df1.loc[((df1['star_rating'] > 8) & (df1['duration'] > 130))]
#print(r)

#    "# add a weekday column to bikes_df"
df1['weekday'] = '0'
#print(df1)
del df1['weekday']
#print(df1)

#     "# remove column 'Unnamed: 1' from bikes_df"
#"""""""""""""""asssskk thiiiss"""

#    "# remove row no. 1 from bikes_df"
#print(df2)
#df2 = df2.drop([0], axis=0)
#print(df2)

#  "Any groupby operation involves one of the following operations on the original object. They are −\n",
#    "- Splitting the Object\n",
#    "- Applying a function\n",
#    "- Combining the results\n",
#    "In many situations, we split the data into sets and we apply some functionality on each subset. In the apply functionality, we can perform the following operations −\n",
#    "- **Aggregation** − computing a summary statistic\n",
#    "- **Transformation** − perform some group-specific operation\n",
#    "- **Filtration** − discarding the data with some condition"

#    "# group imdb_df by movie genres"
daa = df1.groupby('genre')
#print(daa.first())

#    "# get crime movies group"

#r = daa.first().loc[daa['genre'] == 'Crime']
#print(r)

#    "# get mean of movie durations for each group"

grouped_df=df1.groupby('genre').agg([np.mean])
print(grouped_df)

#    "# change duration of all movies in a particular genre to mean duration of the group"

#####"""""""""""""""""""""""AAAAASSSSSSKKKKKK"""

#    "# drop groups/genres that do not have average movie duration greater than 120."
####""""""""""""""""""AAAAAAAASSSSSKK""""""""""
# Out:
#           star_rating    duration
#                  mean        mean
# genre
# Action       7.884559  126.485294
# Adventure    7.933333  134.840000
# Animation    7.914516   96.596774
# Biography    7.862338  131.844156
# Comedy       7.822436  107.602564
# Crime        7.916935  122.298387
# Drama        7.902518  126.539568
# Family       7.850000  107.500000
# Fantasy      7.700000  112.000000
# Film-Noir    8.033333   97.333333
# History      8.000000   66.000000
# Horror       7.806897  102.517241
# Mystery      7.975000  115.625000
# Sci-Fi       7.920000  109.000000
# Thriller     7.680000  114.200000
# Western      8.255556  136.666667
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-5f474178d852> in <module>
#     138 #####"""""""""""""""""""""""AAAAASSSSSSKKKKKK"""
#     139
# --> 140 i = grouped_df[(grouped_df.duration < 120)].index
# ...
